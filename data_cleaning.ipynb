# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Explanation and walkthrough

# %% [markdown]
# - Number of users after cleaning: 359,788
# - Number of books after cleaning: 452,982
# - Number of reviews after cleaning: 6,555,799

# %% [markdown]
# # Clean Book Data, Load Author Data + Genres

# %%
df = pd.read_json('/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_children.json', lines=True)
df.head()
# Out:
#          isbn  text_reviews_count    series country_code language_code  \
# 0  1599150603                   7        []           US
# 1  1934876569                   6  [151854]           US
# 2  0590417010                 193        []           US           eng
# 3  0915190575                   4        []           US
# 4  1416904999                   4        []           US
#
#                                      popular_shelves asin is_ebook  \
# 0  [{'count': '56', 'name': 'to-read'}, {'count':...         false
# 1  [{'count': '515', 'name': 'to-read'}, {'count'...         false
# 2  [{'count': '450', 'name': 'to-read'}, {'count'...         false
# 3  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
# 4  [{'count': '8', 'name': 'to-read'}, {'count': ...         false
#
#    average_rating kindle_asin  ... publication_month edition_information  \
# 0            4.13  B00DU10PUG  ...                 9
# 1            4.22              ...                 3
# 2            4.43  B017RORXNI  ...                 9
# 3            4.29              ...
# 4            3.57              ...                 6
#
#   publication_year                                                url  \
# 0             2006  https://www.goodreads.com/book/show/287141.The...
# 1             2009  https://www.goodreads.com/book/show/6066812-al...
# 2             1995  https://www.goodreads.com/book/show/89378.Dog_...
# 3                   https://www.goodreads.com/book/show/3209312-mo...
# 4             2005  https://www.goodreads.com/book/show/1698376.Wh...
#
#                                            image_url  book_id ratings_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...   287141            46
# 1  https://images.gr-assets.com/books/1316637798m...  6066812            98
# 2  https://images.gr-assets.com/books/1360057676m...    89378          1331
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  3209312            11
# 4  https://s.gr-assets.com/assets/nophoto/book/11...  1698376            23
#
#    work_id                                              title  \
# 0   278578                      The Aeneid for Boys and Girls
# 1   701117  All's Fairy in Love and War (Avalon: Web of Ma...
# 2    86259                                         Dog Heaven
# 3  3242879  Moths and Mothers, Feathers and Fathers: A Sto...
# 4  1695373                                    What Do You Do?
#
#                                 title_without_series
# 0                      The Aeneid for Boys and Girls
# 1  All's Fairy in Love and War (Avalon: Web of Ma...
# 2                                         Dog Heaven
# 3  Moths and Mothers, Feathers and Fathers: A Sto...
# 4                                    What Do You Do?
#
# [5 rows x 29 columns]

# %%
def clean_books_df(file_path):
    df = pd.read_json(file_path, lines=True)

    columns_to_drop = [
        'kindle_asin', 'popular_shelves', 'asin', 'is_ebook', 'isbn13',
        'edition_information', 'url', 'image_url', 'title_without_series',
        'language_code', 'similar_books', 'format', 'link', 'work_id',
        'text_reviews_count', 'ratings_count'
    ]
    df.drop(columns=[col for col in columns_to_drop if col in df.columns], axis=1, inplace=True)

    nona_columns = [
        'book_id', 'isbn', 'title', 'average_rating', 'authors', 'publisher',
        'description', 'country_code', 'num_pages', 'publication_day',
        'publication_month', 'publication_year'
    ]
    df[nona_columns] = df[nona_columns].replace('', np.nan)
    df.dropna(subset=nona_columns, inplace=True)

    df['publication_year'] = df['publication_year'].astype(str)
    df = df[df['publication_year'].str.len() == 4]

    df['publication_day'] = df['publication_day'].apply(lambda x: f"{int(x):02d}" if pd.notnull(x) else x)
    df['publication_month'] = df['publication_month'].apply(lambda x: f"{int(x):02d}" if pd.notnull(x) else x)

    df['publication_date'] = df['publication_day'] + '-' + df['publication_month'] + '-' + df['publication_year']
    df['publication_date'] = pd.to_datetime(df['publication_date'], format='%d-%m-%Y', errors='coerce')

    df.dropna(subset=['publication_date'], inplace=True)

    desired_column_order = [
        'book_id', 'isbn', 'title', 'average_rating', 'authors', 'publisher',
        'description', 'series', 'country_code', 'num_pages', 'publication_date'
    ]
    df = df[desired_column_order]

    return df

# %%
book_children_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_children.csv'
book_children_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_children.json'
book_children = clean_books_df(book_children_path)
book_children.to_csv(book_children_output_path, index=False)
book_children.head()
# Out:
#    book_id        isbn                                              title  \
# 0   287141  1599150603                      The Aeneid for Boys and Girls
# 1  6066812  1934876569  All's Fairy in Love and War (Avalon: Web of Ma...
# 2    89378  0590417010                                         Dog Heaven
# 4  1698376  1416904999                                    What Do You Do?
# 7  3631900  0884482987                Amadi's Snowman: A Story of Reading
#
#    average_rating                                            authors  \
# 0            4.13             [{'author_id': '3041852', 'role': ''}]
# 1            4.22               [{'author_id': '19158', 'role': ''}]
# 2            4.43                [{'author_id': '5411', 'role': ''}]
# 4            3.57              [{'author_id': '169159', 'role': ''}]
# 7            3.89  [{'author_id': '1540277', 'role': ''}, {'autho...
#
#                   publisher  \
# 0      Yesterday's Classics
# 1                Seven Seas
# 2            Blue Sky Press
# 4              Little Simon
# 7  Tilbury House Publishers
#
#                                          description    series country_code  \
# 0  Relates in vigorous prose the tale of Aeneas, ...        []           US
# 1  To Kara's astonishment, she discovers that a p...  [151854]           US
# 2  In Newbery Medalist Cynthia Rylant's classic b...        []           US
# 4  WHAT DO YOU DO?\nA hen lays eggs...\nA cow giv...        []           US
# 7  When Amadi disobeys his mother and runs off to...        []           US
#
#   num_pages publication_date
# 0       162       2006-09-13
# 1       216       2009-03-03
# 2        40       1995-09-01
# 4        24       2005-06-01
# 7        32       2008-05-01

# %%
book_fantasy_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_fantasy.csv'
book_fantasy_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_fantasy_paranormal.json'
book_fantasy = clean_books_df(book_fantasy_path)
book_fantasy.to_csv(book_fantasy_output_path, index=False)
book_fantasy.head()
# Out:
#      book_id        isbn                                              title  \
# 1    6066812  1934876569  All's Fairy in Love and War (Avalon: Web of Ma...
# 8   21401181  0698143760                           Half Bad (Half Life, #1)
# 12    780917  0765313286     The Serpent and the Rose (War of the Rose, #1)
# 16  16693030  1406346950                                    A Monster Calls
# 23  18656391  0316219169                                    Baptism of Fire
#
#     average_rating                                 authors  \
# 1             4.22    [{'author_id': '19158', 'role': ''}]
# 8             3.80  [{'author_id': '7314532', 'role': ''}]
# 12            3.49   [{'author_id': '410348', 'role': ''}]
# 16            4.37   [{'author_id': '370361', 'role': ''}]
# 23            4.36    [{'author_id': '38569', 'role': ''}]
#
#                      publisher  \
# 1                   Seven Seas
# 8            Viking Children's
# 12                   Tor Books
# 16  Walker Childrens Hardbacks
# 23                       Orbit
#
#                                           description    series country_code  \
# 1   To Kara's astonishment, she discovers that a p...  [151854]           US
# 8   Wanted by no one.\nHunted by everyone.\nSixtee...  [493993]           US
# 12  The beautiful Averil is heir to the Duchy of Q...  [152365]           US
# 16  An unflinching, darkly funny, and deeply movin...        []           US
# 23  The Wizards Guild has been shattered by a coup...  [159489]           US
#
#    num_pages publication_date
# 1        216       2009-03-03
# 8        416       2014-03-04
# 12       320       2007-03-06
# 16       240       2012-11-01
# 23       288       2014-06-24

# %%
book_history_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_history.csv'
book_history_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_history_biography.json'
book_history = clean_books_df(book_history_path)
book_history.to_csv(book_history_output_path, index=False)
book_history.head()
# Out:
#     book_id        isbn                                              title  \
# 0    287141  1599150603                      The Aeneid for Boys and Girls
# 1   6066814  184737297X          Crowner Royal (Crowner John Mystery, #13)
# 2     89377  037583687X                                  Penny from Heaven
# 4  18628480  8864116435                                             Stoner
# 7  13707894  0393929876  Eighteenth-Century Europe: Tradition and Progr...
#
#    average_rating                                            authors  \
# 0            4.13             [{'author_id': '3041852', 'role': ''}]
# 1            3.93               [{'author_id': '37778', 'role': ''}]
# 2            3.98              [{'author_id': '137561', 'role': ''}]
# 4            4.28  [{'author_id': '51229', 'role': ''}, {'author_...
# 7            3.57  [{'author_id': '8070', 'role': ''}, {'author_i...
#
#                               publisher  \
# 0                  Yesterday's Classics
# 1                   Simon & Schuster UK
# 2  Random House Books for Young Readers
# 4                                  Fazi
# 7                W. W. Norton & Company
#
#                                          description    series country_code  \
# 0  Relates in vigorous prose the tale of Aeneas, ...        []           US
# 1  London, 1196. At the command of Richard the Li...  [169353]           US
# 2  It's 1953 and 11-year-old Penny dreams of a su...        []           US
# 4  Stoner e il racconto della vita di un uomo tra...        []           US
# 7  The new second edition of the standard text on...  [414880]           US
#
#   num_pages publication_date
# 0       162       2006-09-13
# 1       400       2009-04-06
# 2       288       2006-07-25
# 4       332       2012-05-28
# 7       362       2012-01-09

# %%
book_mistery_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_mistery.csv'
book_mistery_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_mystery_thriller_crime.json'
book_mistery = clean_books_df(book_mistery_path)
book_mistery.to_csv(book_mistery_output_path, index=False)
book_mistery.head()
# Out:
#      book_id        isbn                                      title  \
# 0    6066814  184737297X  Crowner Royal (Crowner John Mystery, #13)
# 7    2805495  0752844458            Wycliffe and the Cycle of Death
# 8   22722787  8293326247                 The Cost of Doing Business
# 10  17368265  1619694611               White Fire (Pendergast, #13)
# 11    778285  0345367650              Polar Star (Arkady Renko, #2)
#
#     average_rating                                            authors  \
# 0             3.93               [{'author_id': '37778', 'role': ''}]
# 7             3.61             [{'author_id': '1533165', 'role': ''}]
# 8             4.14             [{'author_id': '4577517', 'role': ''}]
# 10            4.07  [{'author_id': '12577', 'role': ''}, {'author_...
# 11            3.99                [{'author_id': '8258', 'role': ''}]
#
#                    publisher  \
# 0        Simon & Schuster UK
# 7                      Orion
# 8                  280 Steps
# 10  Grand Central Publishing
# 11          Ballantine Books
#
#                                           description    series country_code  \
# 0   London, 1196. At the command of Richard the Li...  [169353]           US
# 7   A respectable bookseller is found bludgeoned a...  [326237]           US
# 8   "Poetic, down trodden and nihilistic, Jonathan...        []           US
# 10  Past and present collide as Special Agent Pend...  [510553]           US
# 11  In the long-awaited sequel to Gorky Park, Arka...  [163090]           US
#
#    num_pages publication_date
# 0        400       2009-04-06
# 7        320       2001-08-02
# 8        228       2014-11-04
# 10        13       2013-11-12
# 11       366       1990-06-13

# %%
book_poetry_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_poetry.csv'
book_poetry_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_poetry.json'
book_poetry = clean_books_df(book_poetry_path)
book_poetry.to_csv(book_poetry_output_path, index=False)
book_poetry.head()
# Out:
#      book_id        isbn                              title  average_rating  \
# 1   22466716  0811223981           Fairy Tales: Dramolettes            3.83
# 3     926667  0156182890                 The Cocktail Party            3.71
# 4   29065952  1942004192    Louder Than Everything You Love            5.00
# 10  24849837  0692265295  Naked Soul: The Erotic Love Poems            3.95
# 12  20544060  1927575249                Black Liquor: Poems            4.00
#
#                                               authors         publisher  \
# 1   [{'author_id': '16073', 'role': ''}, {'author_...    New Directions
# 3                [{'author_id': '18540', 'role': ''}]     Mariner Books
# 4             [{'author_id': '14308759', 'role': ''}]  ELJ Publications
# 10            [{'author_id': '13260036', 'role': ''}]  Naked Soul Press
# 12              [{'author_id': '547708', 'role': ''}]     Caitlin Press
#
#                                           description series country_code  \
# 1   Fairy Tales gathers the unconventional verse d...     []           US
# 3   A modern verse play about the search for meani...     []           US
# 4   Louder Than Everything You Love is about trans...     []           US
# 10  "Erotic poetry that evokes feelings of joy, ha...     []           US
# 12  Dennis E. Bolen's forthcoming volume of poetry...     []           US
#
#    num_pages publication_date
# 1        128       2015-04-20
# 3        190       1964-03-18
# 4        118       2015-12-23
# 10       172       2015-01-09
# 12       128       2013-09-01

# %%
book_romance_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_romance.csv'
book_romance_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_romance.json'
book_romance = clean_books_df(book_romance_path)
book_romance.to_csv(book_poetry_output_path, index=False)
book_romance.head()
# Out:
#      book_id        isbn                       title  average_rating  \
# 2    3209316  1597371289                        Emma            3.99
# 12  18283095  4091838758  ノ・ゾ・キ・ア・ナ 8 [Nozoki Ana 8]            3.71
# 14  22499086  1627988912      Love Means... Patience            4.11
# 15   2250580  1933617640     A.I. Revolution, Vol. 1            3.44
# 21  24614930  1921901993                   The Falls            4.08
#
#                                               authors  \
# 2                 [{'author_id': '1265', 'role': ''}]
# 12  [{'author_id': '7066263', 'role': ''}, {'autho...
# 14             [{'author_id': '2953781', 'role': ''}]
# 15             [{'author_id': '1015982', 'role': ''}]
# 21             [{'author_id': '5137697', 'role': ''}]
#
#                              publisher  \
# 2                     Brilliance Audio
# 12                       Xiao Xue Guan
# 14                  Dreamspinner Press
# 15                            Go! Comi
# 21  Michael Joseph / Penguin Australia
#
#                                           description    series country_code  \
# 2   The funny and heartwarming story of a young la...        []           US
# 12  Si kiXue noCun Zai ga, tsuinimochidukinibarete...  [529990]           US
# 14  A Love Means... Story\nYears after his dischar...  [629995]           US
# 15  Like everyone else in the future, Sui's used t...  [910384]           US
# 21  For as long as she can remember, Teagan Bliss ...        []           US
#
#    num_pages publication_date
# 2        544       2005-09-25
# 12       188       2011-06-30
# 14       200       2014-05-23
# 15       206       2007-01-02
# 21       402       2015-04-22

# %%
book_ya_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/book_youngadult.csv'
book_ya_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_books_young_adult.json'
book_ya = clean_books_df(book_ya_path)
book_ya.to_csv(book_poetry_output_path, index=False)
book_ya.head()
# Out:
#      book_id        isbn                                   title  \
# 2   21401181  0698143760                Half Bad (Half Life, #1)
# 4   22642971  0990662616                       The Body Electric
# 5   31556136  0062373374                              Like Water
# 9   25421507  1941103863                              The Ticket
# 10  25414982  1634760123  Out of Order (The Survivor's Club, #1)
#
#     average_rating                                  authors  \
# 2             3.80   [{'author_id': '7314532', 'role': ''}]
# 4             3.71   [{'author_id': '4018722', 'role': ''}]
# 5             3.89   [{'author_id': '6537142', 'role': ''}]
# 9             3.82    [{'author_id': '539783', 'role': ''}]
# 10            3.85  [{'author_id': '13850345', 'role': ''}]
#
#                    publisher  \
# 2          Viking Children's
# 4         Scripturient Books
# 5              Balzer + Bray
# 9   Firefly Southern Fiction
# 10         Harmony Ink Press
#
#                                           description    series country_code  \
# 2   Wanted by no one.\nHunted by everyone.\nSixtee...  [493993]           US
# 4   The future world is at peace.\nElla Shepherd h...        []           US
# 5   A gorgeously written and deeply felt literary ...        []           US
# 9   Librarian Note: See Alternate Cover Edition ....        []           US
# 10  Corinna "Corey" Nguyen's life seems perfectly ...  [926363]           US
#
#    num_pages publication_date
# 2        416       2014-03-04
# 4        351       2014-10-06
# 5        304       2017-10-17
# 9        210       2015-05-20
# 10       180       2015-03-21

# %%
dataframes = [book_ya, book_romance, book_poetry, book_mistery, book_history, book_fantasy, book_children]

book_joined = pd.concat(dataframes, ignore_index=True)

book_joined.shape[0]
# Out:
# 522438

# %%
book_joined.head()
# Out:
#     book_id        isbn                                   title  \
# 0  21401181  0698143760                Half Bad (Half Life, #1)
# 1  22642971  0990662616                       The Body Electric
# 2  31556136  0062373374                              Like Water
# 3  25421507  1941103863                              The Ticket
# 4  25414982  1634760123  Out of Order (The Survivor's Club, #1)
#
#    average_rating                                  authors  \
# 0            3.80   [{'author_id': '7314532', 'role': ''}]
# 1            3.71   [{'author_id': '4018722', 'role': ''}]
# 2            3.89   [{'author_id': '6537142', 'role': ''}]
# 3            3.82    [{'author_id': '539783', 'role': ''}]
# 4            3.85  [{'author_id': '13850345', 'role': ''}]
#
#                   publisher  \
# 0         Viking Children's
# 1        Scripturient Books
# 2             Balzer + Bray
# 3  Firefly Southern Fiction
# 4         Harmony Ink Press
#
#                                          description    series country_code  \
# 0  Wanted by no one.\nHunted by everyone.\nSixtee...  [493993]           US
# 1  The future world is at peace.\nElla Shepherd h...        []           US
# 2  A gorgeously written and deeply felt literary ...        []           US
# 3  Librarian Note: See Alternate Cover Edition ....        []           US
# 4  Corinna "Corey" Nguyen's life seems perfectly ...  [926363]           US
#
#   num_pages publication_date
# 0       416       2014-03-04
# 1       351       2014-10-06
# 2       304       2017-10-17
# 3       210       2015-05-20
# 4       180       2015-03-21

# %%
book_joined = book_joined.drop_duplicates(subset='book_id', keep='first')
book_joined.shape[0]
# Out:
# 452982

# %%
authors_df = pd.read_json('/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_book_authors.json', lines=True)
authors_df.head()
# Out:
#    average_rating  author_id  text_reviews_count              name  \
# 0            3.98     604031                   7  Ronald J. Fields
# 1            4.08     626222               28716     Anita Diamant
# 2            3.92      10333                5075    Barbara Hambly
# 3            3.68       9212               36262   Jennifer Weiner
# 4            3.82     149918                  96     Nigel Pennick
#
#    ratings_count
# 0             49
# 1         546796
# 2         122118
# 3         888522
# 4           1740

# %%
expanded_authors = book_joined['authors'].apply(pd.Series).stack().reset_index(level=1, drop=True).to_frame('author_info')

expanded_authors = expanded_authors.join(book_joined.drop('authors', axis=1), how='left')

expanded_authors['author_id'] = expanded_authors['author_info'].apply(lambda x: x.get('author_id'))

# %%
expanded_authors['author_id'] = expanded_authors['author_id'].astype(str)
authors_df['author_id'] = authors_df['author_id'].astype(str)

expanded_authors = expanded_authors.merge(authors_df[['author_id', 'name']], on='author_id', how='left')

expanded_authors['author_info'] = expanded_authors.apply(lambda row: {**row['author_info'], 'name': row['name']}, axis=1)

# %%
reconstructed_authors = expanded_authors.groupby('book_id')['author_info'].apply(list).reset_index()

book_joined = book_joined.merge(reconstructed_authors, on='book_id', how='left')

# %%
book_joined.drop('authors', axis=1, inplace=True)

book_joined.rename(columns={'author_info': 'authors'}, inplace=True)

book_joined.head()
# Out:
#     book_id        isbn                                   title  \
# 0  21401181  0698143760                Half Bad (Half Life, #1)
# 1  22642971  0990662616                       The Body Electric
# 2  31556136  0062373374                              Like Water
# 3  25421507  1941103863                              The Ticket
# 4  25414982  1634760123  Out of Order (The Survivor's Club, #1)
#
#    average_rating                 publisher  \
# 0            3.80         Viking Children's
# 1            3.71        Scripturient Books
# 2            3.89             Balzer + Bray
# 3            3.82  Firefly Southern Fiction
# 4            3.85         Harmony Ink Press
#
#                                          description    series country_code  \
# 0  Wanted by no one.\nHunted by everyone.\nSixtee...  [493993]           US
# 1  The future world is at peace.\nElla Shepherd h...        []           US
# 2  A gorgeously written and deeply felt literary ...        []           US
# 3  Librarian Note: See Alternate Cover Edition ....        []           US
# 4  Corinna "Corey" Nguyen's life seems perfectly ...  [926363]           US
#
#   num_pages publication_date  \
# 0       416       2014-03-04
# 1       351       2014-10-06
# 2       304       2017-10-17
# 3       210       2015-05-20
# 4       180       2015-03-21
#
#                                              authors
# 0  [{'author_id': '7314532', 'role': '', 'name': ...
# 1  [{'author_id': '4018722', 'role': '', 'name': ...
# 2  [{'author_id': '6537142', 'role': '', 'name': ...
# 3  [{'author_id': '539783', 'role': '', 'name': '...
# 4  [{'author_id': '13850345', 'role': '', 'name':...

# %%
multiple_authors_case = book_joined[book_joined['authors'].apply(lambda x: len(x) > 1)]

if not multiple_authors_case.empty:
    display_case = multiple_authors_case.iloc[0]
    print("Authors:", display_case['authors'])
# Out:
# Authors: [{'author_id': '2905297', 'role': '', 'name': 'Lauren Kate'}, {'author_id': '1144378', 'role': '', 'name': 'Justine Eyre'}]

# %%
genres_df = pd.read_json('/content/drive/MyDrive/Recommender Systems/GroupProject/Books/goodreads_book_genres_initial.json', lines=True)
genres_df.head()
# Out:
#    book_id                                             genres
# 0  5333265      {'history, historical fiction, biography': 1}
# 1  1333909  {'fiction': 219, 'history, historical fiction,...
# 2  7327624  {'fantasy, paranormal': 31, 'fiction': 8, 'mys...
# 3  6066819  {'fiction': 555, 'romance': 23, 'mystery, thri...
# 4   287140                                 {'non-fiction': 3}

# %%
book_joined['book_id'] = book_joined['book_id'].astype(str)
genres_df['book_id'] = genres_df['book_id'].astype(str)

book_joined = book_joined.merge(genres_df[['book_id', 'genres']], on='book_id', how='left')

# %%
books_df = book_joined

output_csv_books = '/content/drive/MyDrive/Recommender Systems/GroupProject/Books/CleanedData/books_df.csv'

books_df.to_csv(output_csv_books, index=False)

# %%
books_df.shape[0]
# Out:
# 452982

# %% [markdown]
# # Clean Review Data

# %%
review_df = pd.read_json('/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_poetry.json', lines=True)

# %%
review_df.head()
# Out:
#                             user_id  book_id  \
# 0  3ca7375dba942a760e53b726c472a7dd   402128
# 1  0ef32090550901ead25cb0ea21c4d36b    92270
# 2  0ef32090550901ead25cb0ea21c4d36b   908708
# 3  d37b46b2190ed7c518259f29b47a9b36   253264
# 4  af157d0205b8a901dee6d4a2aed7e6ad    70885
#
#                           review_id  rating  \
# 0  28423ff309bc896c071a8d9df4a10e8a       5
# 1  2db1180992e2b0b1631a3ac5644bde84       5
# 2  bca57fa40e92c9261b00b03dbebd96fe       4
# 3  cb1ebc02d8b2aff15735d513877463ce       5
# 4  8dca128b8e869048a7442c18659dbece       5
#
#                                          review_text  \
# 0  I have three younger siblings and we grew up w...
# 1          This is my favorite collection of poetry.
# 2      He's so disturbing. So very, very disturbing.
# 3  I just reread this play for a class I am takin...
# 4  Cuanto mas leo, mas me gusta. Su poesia es env...
#
#                        date_added                    date_updated  \
# 0  Tue Jun 12 08:59:04 -0700 2012  Fri Jun 15 11:41:12 -0700 2012
# 1  Mon Apr 14 18:42:40 -0700 2014  Mon Apr 14 18:43:05 -0700 2014
# 2  Tue Apr 22 13:58:10 -0700 2008  Tue Apr 22 13:58:33 -0700 2008
# 3  Wed Sep 27 19:08:08 -0700 2017  Sat Sep 30 06:39:45 -0700 2017
# 4  Thu Jun 18 20:00:03 -0700 2015  Thu Jun 18 20:01:29 -0700 2015
#
#                           read_at                      started_at  n_votes  \
# 0                                                                        0
# 1  Wed Jan 01 00:00:00 -0800 1997                                        0
# 2                                                                        0
# 3  Wed Sep 27 00:00:00 -0700 2017  Tue Sep 26 00:00:00 -0700 2017        1
# 4  Thu Jun 18 00:00:00 -0700 2015  Tue Jun 16 00:00:00 -0700 2015        0
#
#    n_comments
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
books_df['book_id'] = books_df['book_id'].astype(str)

# %%
def clean_review_df(review_df_path):
    review_df = pd.read_json(review_df_path, lines=True)

    review_df.dropna(subset=['rating', 'review_text', 'date_added'], inplace=True)

    review_df = review_df[(review_df['review_text'] != '') & (review_df['date_added'] != '')]

    review_df.drop(['date_updated', 'n_comments', 'started_at'], axis=1, inplace=True)

    review_df['book_id'] = review_df['book_id'].astype(str)

    review_df = review_df[review_df['book_id'].isin(books_df['book_id'])]

    return review_df

# %%
review_ya_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_ya.csv'
review_ya_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_young_adult.json'
review_ya = clean_review_df(review_ya_path)
review_ya.to_csv(review_ya_output_path, index=False)
review_ya.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d   2767052
# 2  f8a89075dc6de14857561522e729f82c  18053080
# 3  f8a89075dc6de14857561522e729f82c  17383543
# 4  f8a89075dc6de14857561522e729f82c  16651458
# 5  f8a89075dc6de14857561522e729f82c  10782699
#
#                           review_id  rating  \
# 0  248c011811e945eca861b5c31a549291       5
# 2  785c8db878f4009da9741dea51f641da       4
# 3  34dc3c45d07e82718b05e73167259aef       2
# 4  d8d6b590780256fef7ae4a9550fe3e0d       5
# 5  972ce1267de0213e3032c685386890e6       5
#
#                                          review_text  \
# 0  I cracked and finally picked this up. Very enj...
# 2  Though the book started out slow and only star...
# 3  *Update - 10/27/13* - After some sleep, I thin...
# 4  This is a moving, heartbreaking, view into a l...
# 5  I never thought I would enjoy a zombie books w...
#
#                        date_added                         read_at  n_votes
# 0  Wed Jan 13 13:38:25 -0800 2010  Sun Mar 25 00:00:00 -0700 2012       24
# 2  Sat Jan 11 17:58:41 -0800 2014  Sat Apr 12 00:00:00 -0700 2014        0
# 3  Sun Apr 21 19:42:28 -0700 2013  Sat Oct 26 00:00:00 -0700 2013        0
# 4  Fri Jan 11 11:42:42 -0800 2013  Mon Jan 14 00:00:00 -0800 2013        0
# 5  Tue Oct 30 21:32:34 -0700 2012  Thu May 01 00:00:00 -0700 2014        0

# %%
review_poetry_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_poetry.csv'
review_poetry_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_poetry.json'
review_poetry = clean_review_df(review_poetry_path)
review_poetry.to_csv(review_poetry_output_path, index=False)
review_poetry.head()
# Out:
#                             user_id book_id                         review_id  \
# 0  3ca7375dba942a760e53b726c472a7dd  402128  28423ff309bc896c071a8d9df4a10e8a
# 1  0ef32090550901ead25cb0ea21c4d36b   92270  2db1180992e2b0b1631a3ac5644bde84
# 2  0ef32090550901ead25cb0ea21c4d36b  908708  bca57fa40e92c9261b00b03dbebd96fe
# 3  d37b46b2190ed7c518259f29b47a9b36  253264  cb1ebc02d8b2aff15735d513877463ce
# 4  af157d0205b8a901dee6d4a2aed7e6ad   70885  8dca128b8e869048a7442c18659dbece
#
#    rating                                        review_text  \
# 0       5  I have three younger siblings and we grew up w...
# 1       5          This is my favorite collection of poetry.
# 2       4      He's so disturbing. So very, very disturbing.
# 3       5  I just reread this play for a class I am takin...
# 4       5  Cuanto mas leo, mas me gusta. Su poesia es env...
#
#                        date_added                         read_at  n_votes
# 0  Tue Jun 12 08:59:04 -0700 2012                                        0
# 1  Mon Apr 14 18:42:40 -0700 2014  Wed Jan 01 00:00:00 -0800 1997        0
# 2  Tue Apr 22 13:58:10 -0700 2008                                        0
# 3  Wed Sep 27 19:08:08 -0700 2017  Wed Sep 27 00:00:00 -0700 2017        1
# 4  Thu Jun 18 20:00:03 -0700 2015  Thu Jun 18 00:00:00 -0700 2015        0

# %%
review_history_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_history.csv'
review_history_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_history_biography.json'
review_history = clean_review_df(review_history_path)
review_history.to_csv(review_history_output_path, index=False)
review_history.head()
# Out:
#                             user_id   book_id  \
# 2  8842281e1d1347389f2ab93d60773d4d  27161156
# 5  8842281e1d1347389f2ab93d60773d4d  22551730
# 6  8842281e1d1347389f2ab93d60773d4d    137554
# 7  8842281e1d1347389f2ab93d60773d4d      5064
# 9  8842281e1d1347389f2ab93d60773d4d     40955
#
#                           review_id  rating  \
# 2  ced5675e55cd9d38a524743f5c40996e       0
# 5  754710070f38e1c59a45f6a85473b836       4
# 6  6f74c6ca4ac2be7c71237d4d0fd4623d       0
# 7  da4757c50c0edb081ca124d33db8186b       5
# 9  299706d01666058b1fb2a96b29a1260b       5
#
#                                          review_text  \
# 2  Recommended reading to understand what is goin...
# 5  Another hard to put down nonfiction book from ...
# 6                           Sacca and Nate recommend
# 7  I tore through The Pillars of the Earth, and c...
# 9  A truly inspirational book by a truly inspirat...
#
#                        date_added                         read_at  n_votes
# 2  Wed Nov 09 17:37:04 -0800 2016                                        5
# 5  Thu May 07 13:59:32 -0700 2015  Sat Jul 11 00:00:00 -0700 2015       20
# 6  Thu Mar 20 10:12:34 -0700 2014                                        4
# 7  Sun Mar 02 12:34:19 -0800 2014  Sun Apr 27 00:00:00 -0700 2014        2
# 9  Sun Nov 18 16:31:28 -0800 2012  Fri Apr 17 00:00:00 -0700 2015        5

# %%
review_children_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_children.csv'
review_children_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_children.json'
review_children = clean_review_df(review_children_path)
review_children.to_csv(review_children_output_path, index=False)
review_children.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  23310161
# 1  8842281e1d1347389f2ab93d60773d4d  17290220
# 2  8842281e1d1347389f2ab93d60773d4d   6954929
# 3  8842281e1d1347389f2ab93d60773d4d    460548
# 4  8842281e1d1347389f2ab93d60773d4d  11474551
#
#                           review_id  rating  \
# 0  f4b4b050f4be00e9283c92a814af2670       4
# 1  22d424a2b0057b18fb6ecf017af7be92       5
# 2  50ed4431c451d5677d98dd25ca8ec106       5
# 3  1e4de11dd4fa4b7ffa59b6c69a6b28e9       5
# 4  2065145714bf747083a1c9ce81d5c4fe       5
#
#                                          review_text  \
# 0                        Fun sequel to the original.
# 1  One of my favorite books to read to my 5 year ...
# 2  One of the best and most imaginative childrens...
# 3  My daughter is loving this. Published in the 6...
# 4                  A friend sent me this. Hilarious!
#
#                        date_added                         read_at  n_votes
# 0  Tue Nov 17 11:37:35 -0800 2015                                        7
# 1  Sat Nov 08 08:54:03 -0800 2014  Tue Jan 24 00:00:00 -0800 2017        4
# 2  Thu Oct 23 13:46:20 -0700 2014                                        6
# 3  Mon Dec 02 10:43:59 -0800 2013                                        5
# 4  Wed May 11 22:38:11 -0700 2011  Wed May 11 00:00:00 -0700 2011        5

# %%
review_mystery_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_mystery.csv'
review_mystery_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_mystery_thriller_crime.json'
review_mystery = clean_review_df(review_mystery_path)
review_mystery.to_csv(review_children_output_path, index=False)
review_mystery.head()
# Out:
#                             user_id   book_id  \
# 2  8842281e1d1347389f2ab93d60773d4d  32283133
# 3  8842281e1d1347389f2ab93d60773d4d  17860739
# 5  8842281e1d1347389f2ab93d60773d4d   6652906
# 6  8842281e1d1347389f2ab93d60773d4d   2429135
# 8  8842281e1d1347389f2ab93d60773d4d      7661
#
#                           review_id  rating  \
# 2  8e4d61801907e591018bdc3442a9cf2b       0
# 3  022bb6daffa49adc27f6b20b6ebeb37d       4
# 5  4276918357312212384ac6415ceb9159       3
# 6  efee7a3f620ed640366226caa7b138f0       5
# 8  fc5c2b74043cb5132b5b607c16a68211       3
#
#                                          review_text  \
# 2           http://www.telegraph.co.uk/culture/10...
# 3  An amazing and unique creation: JJ Abrams and ...
# 5  ** spoiler alert ** \n Hooked me equally as we...
# 6  I haven't stayed up until 5am to finish a book...
# 8  A quick read, but I enjoyed the focus on gener...
#
#                        date_added                         read_at  n_votes
# 2  Tue Nov 01 11:09:18 -0700 2016                                        9
# 3  Wed Mar 26 13:51:30 -0700 2014  Sun Sep 21 00:00:00 -0700 2014        7
# 5  Mon Mar 29 15:54:28 -0700 2010  Thu Apr 08 00:00:00 -0700 2010        1
# 6  Mon Mar 15 14:05:04 -0700 2010  Sun Mar 28 00:00:00 -0700 2010       13
# 8  Wed Aug 12 16:34:06 -0700 2009  Sun Aug 09 00:00:00 -0700 2009        0

# %%
review_romance_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_romance.csv'
review_romance_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_romance.json'
review_romance = clean_review_df(review_romance_path)
review_romance.to_csv(review_children_output_path, index=False)
review_romance.head()
# Out:
#                              user_id   book_id  \
# 0   8842281e1d1347389f2ab93d60773d4d      1893
# 5   72fb0d0087d28c832f15776b0d936598   2718668
# 7   7504b2aee1ecb5b2872d3da381c6c91e  15507958
# 10  012515e5802b2e0f42915118c90fa04b   9462815
# 11  012515e5802b2e0f42915118c90fa04b  20572939
#
#                            review_id  rating  \
# 0   5347a776a1703b823ce029d68ae98275       5
# 5   768e4a82b89e36055706857e9268b8e9       5
# 7   63ff74279e46b247cb1754313b160006       4
# 10  a99a5a35d2592795791ebe3e49c57b99       2
# 11  812febaa143162ed49152547ff7a3e08       5
#
#                                           review_text  \
# 0   ** spoiler alert ** \n So the other day Elizab...
# 5   I really enjoyed this book! Chick lit with bra...
# 7   I finished reading this days ago and cant get ...
# 10  Wow I lost it on the last page. Yay for happy ...
# 11  There was sobbing. Quite a lot. \n The last fe...
#
#                         date_added                         read_at  n_votes
# 0   Tue Oct 10 19:08:05 -0700 2006  Sun Oct 01 00:00:00 -0700 2006      155
# 5   Wed Oct 30 11:13:28 -0700 2013                                        0
# 7   Wed Sep 10 19:33:44 -0700 2014  Sun Sep 21 00:00:00 -0700 2014        0
# 10  Sat Nov 08 08:59:14 -0800 2014  Mon Nov 10 12:46:36 -0800 2014        0
# 11  Sun Sep 14 12:55:35 -0700 2014  Mon Sep 15 16:52:15 -0700 2014        0

# %%
review_fantasy_output_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/review_fantasy.csv'
review_fantasy_path = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/goodreads_reviews_fantasy_paranormal.json'
review_fantasy = clean_review_df(review_fantasy_path)
review_fantasy.to_csv(review_children_output_path, index=False)
review_fantasy.head()
# Out:
#                              user_id   book_id  \
# 4   8842281e1d1347389f2ab93d60773d4d  13239822
# 5   8842281e1d1347389f2ab93d60773d4d     62291
# 6   8842281e1d1347389f2ab93d60773d4d     41804
# 7   8842281e1d1347389f2ab93d60773d4d    136251
# 10  8842281e1d1347389f2ab93d60773d4d     34497
#
#                            review_id  rating  \
# 4   a582bfa8efd69d453a5a21a678046b36       3
# 5   e23965adda7ce7e7e415a1339e169065       5
# 6   2bcbe2300fe1801197f9bfe1f1c883ba       5
# 7   132eab4c9a3724493204cc083e0e2ecc       5
# 10  43828b41e8099f892cfee80a8244684a       3
#
#                                           review_text  \
# 4   This book has a great premise, and is full of ...
# 5   ** spoiler alert ** \n Loved it. The epic saga...
# 6   As an engineer I couldn't help but love this b...
# 7   Loved every minute. So sad there isn't another...
# 10  This should be 3.5 stars. I really enjoyed it,...
#
#                         date_added                         read_at  n_votes
# 4   Mon Jul 02 16:04:16 -0700 2012  Wed Aug 15 00:00:00 -0700 2012        7
# 5   Tue Jul 12 12:57:07 -0700 2011  Sat Aug 20 00:00:00 -0700 2011        5
# 6   Wed Mar 25 10:56:59 -0700 2009  Wed Apr 08 00:00:00 -0700 2009       12
# 7   Mon Dec 22 10:38:27 -0800 2008  Sun Jan 02 00:00:00 -0800 2011        6
# 10  Tue Jun 03 16:42:44 -0700 2008  Mon Nov 10 00:00:00 -0800 2008        2

# %%
dataframes_review = [review_ya, review_romance, review_poetry, review_mystery, review_history, review_fantasy, review_children]

reviews_joined = pd.concat(dataframes_review, ignore_index=True)

# %%
reviews_joined.shape[0]
# Out:
# 8211681

# %%
reviews_joined = reviews_joined.drop_duplicates(subset='review_id', keep='first')
reviews_joined.shape[0]
# Out:
# 6555799

# %%
reviews_joined.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d   2767052
# 1  f8a89075dc6de14857561522e729f82c  18053080
# 2  f8a89075dc6de14857561522e729f82c  17383543
# 3  f8a89075dc6de14857561522e729f82c  16651458
# 4  f8a89075dc6de14857561522e729f82c  10782699
#
#                           review_id  rating  \
# 0  248c011811e945eca861b5c31a549291       5
# 1  785c8db878f4009da9741dea51f641da       4
# 2  34dc3c45d07e82718b05e73167259aef       2
# 3  d8d6b590780256fef7ae4a9550fe3e0d       5
# 4  972ce1267de0213e3032c685386890e6       5
#
#                                          review_text  \
# 0  I cracked and finally picked this up. Very enj...
# 1  Though the book started out slow and only star...
# 2  *Update - 10/27/13* - After some sleep, I thin...
# 3  This is a moving, heartbreaking, view into a l...
# 4  I never thought I would enjoy a zombie books w...
#
#                        date_added                         read_at  n_votes
# 0  Wed Jan 13 13:38:25 -0800 2010  Sun Mar 25 00:00:00 -0700 2012       24
# 1  Sat Jan 11 17:58:41 -0800 2014  Sat Apr 12 00:00:00 -0700 2014        0
# 2  Sun Apr 21 19:42:28 -0700 2013  Sat Oct 26 00:00:00 -0700 2013        0
# 3  Fri Jan 11 11:42:42 -0800 2013  Mon Jan 14 00:00:00 -0800 2013        0
# 4  Tue Oct 30 21:32:34 -0700 2012  Thu May 01 00:00:00 -0700 2014        0

# %%
reviews_df = reviews_joined

output_csv_reviews = '/content/drive/MyDrive/Recommender Systems/GroupProject/Reviews/CleanedData/reviews_df.csv'

reviews_df.to_csv(output_csv_reviews, index=False)

# %% [markdown]
# # Create User Dataframe

# %%
user_reviews_count = reviews_df.groupby('user_id')['review_id'].count().reset_index(name='number_of_reviews')

# %%
users_df = user_reviews_count

# %%
print(users_df.head())
# Out:
#                             user_id  number_of_reviews
# 0  00000377eea48021d3002730d56aca9a                  3
# 1  00009e46d18f223a82b22da38586b605                 54
# 2  0000c3d51aa099745e93a4e99c4856c8                 97
# 3  0001085188e302fc6b2568de45a5f56b                  2
# 4  00013f3df6711fc887013c9692de4416                  1

# %%
output_csv_users = '/content/drive/MyDrive/Recommender Systems/GroupProject/users_df.csv'

users_df.to_csv(output_csv_users, index=False)

# %%
users_df.shape[0]
# Out:
# 359788

# %%
reviews_df.shape[0]
# Out:
# 6555799

# %%
books_df.shape[0]
# Out:
# 452982
